# %%
from TestER import TestEnergyRequirements
from TestG import TestGoals
from TestWorkout import TestWorkoutSchedule
from TestMacro import TestMacros
from TestPS import TestPersonalSummary
import unittest

def suite():
    suite = unittest.TestSuite()

    suite.addTest(unittest.makeSuite(TestPersonalSummary))
    suite.addTest(unittest.makeSuite(TestEnergyRequirements))
    suite.addTest(unittest.makeSuite(TestGoals))
    suite.addTest(unittest.makeSuite(TestWorkoutSchedule))
    suite.addTest(unittest.makeSuite(TestMacros))

    return suite

if __name__ == '__main__':
    runner = unittest.TextTestRunner(verbosity=2)
    runner.run(suite())
# Out:
# /var/folders/8n/wv_w9rps1lx52_4v0h5449y40000gn/T/ipykernel_68519/3222551724.py:11: DeprecationWarning: unittest.makeSuite() is deprecated and will be removed in Python 3.13. Please use unittest.TestLoader.loadTestsFromTestCase() instead.
#   suite.addTest(unittest.makeSuite(TestPersonalSummary))
# /var/folders/8n/wv_w9rps1lx52_4v0h5449y40000gn/T/ipykernel_68519/3222551724.py:12: DeprecationWarning: unittest.makeSuite() is deprecated and will be removed in Python 3.13. Please use unittest.TestLoader.loadTestsFromTestCase() instead.
#   suite.addTest(unittest.makeSuite(TestEnergyRequirements))
# /var/folders/8n/wv_w9rps1lx52_4v0h5449y40000gn/T/ipykernel_68519/3222551724.py:13: DeprecationWarning: unittest.makeSuite() is deprecated and will be removed in Python 3.13. Please use unittest.TestLoader.loadTestsFromTestCase() instead.
#   suite.addTest(unittest.makeSuite(TestGoals))
# /var/folders/8n/wv_w9rps1lx52_4v0h5449y40000gn/T/ipykernel_68519/3222551724.py:14: DeprecationWarning: unittest.makeSuite() is deprecated and will be removed in Python 3.13. Please use unittest.TestLoader.loadTestsFromTestCase() instead.
#   suite.addTest(unittest.makeSuite(TestWorkoutSchedule))
# /var/folders/8n/wv_w9rps1lx52_4v0h5449y40000gn/T/ipykernel_68519/3222551724.py:15: DeprecationWarning: unittest.makeSuite() is deprecated and will be removed in Python 3.13. Please use unittest.TestLoader.loadTestsFromTestCase() instead.
#   suite.addTest(unittest.makeSuite(TestMacros))
# test_calculate_BMI (TestPS.TestPersonalSummary.test_calculate_BMI) ... ok
# test_collect_info (TestPS.TestPersonalSummary.test_collect_info) ... ok
# test_calculate_TDEE_moderate_activity (TestER.TestEnergyRequirements.test_calculate_TDEE_moderate_activity) ... ok
# test_calculate_TDEE_sedentary_activity (TestER.TestEnergyRequirements.test_calculate_TDEE_sedentary_activity) ... ok
# test_calculate_TDEE_very_active (TestER.TestEnergyRequirements.test_calculate_TDEE_very_active) ... ok
# test_caloric_change_loss (TestG.TestGoals.test_caloric_change_loss) ... ok
# test_caloric_intake (TestG.TestGoals.test_caloric_intake) ... ok
# test_goal_setting_loss (TestG.TestGoals.test_goal_setting_loss) ... ok
# test_1_generate_training_split (TestWorkout.TestWorkoutSchedule.test_1_generate_training_split)
# Test the generate_training_split method. ... ok
# test_2_display_workout_schedule (TestWorkout.TestWorkoutSchedule.test_2_display_workout_schedule)
# Test the display_workout_schedule method. ... ok
# test_3_customize_workout_schedule (TestWorkout.TestWorkoutSchedule.test_3_customize_workout_schedule)
# Test the customize_workout_schedule method. ... ok
# test_4_empty_schedule_display (TestWorkout.TestWorkoutSchedule.test_4_empty_schedule_display)
# Test display_workout_schedule when no schedule is present. ... ok
# test_1_calculate_macro_requirements (TestMacro.TestMacros.test_1_calculate_macro_requirements)
# Test the calculate_macro_requirements method. ... ok
# test_2_customize_macro_distribution (TestMacro.TestMacros.test_2_customize_macro_distribution)
# Test the customize_macro_distribution method. ... ok
# test_3_generate_nutrition_plan (TestMacro.TestMacros.test_3_generate_nutrition_plan)
# Test the generate_nutrition_plan method. ... ok
# test_4_ensure_goals_populated (TestMacro.TestMacros.test_4_ensure_goals_populated)
# Test the ensure_goals_populated method. ... ok
#
# ----------------------------------------------------------------------
# Ran 16 tests in 0.007s
#
# OK
# Setting up the test class for EnergyRequirements.
# Please pick the appropriate activity level:
# +-------------------+----------------------------------------------------+
# | Activity Level    | Description                                        |
# +===================+====================================================+
# | Sedentary         | little to no activity                              |
# +-------------------+----------------------------------------------------+
# | Lightly Active    | 1-3 days per week of light activity                |
# +-------------------+----------------------------------------------------+
# | Moderately Active | moderate exercise 3-5 days per week                |
# +-------------------+----------------------------------------------------+
# | Very Active       | rigorous exercise, 6-7 days per week               |
# +-------------------+----------------------------------------------------+
# | Extra Active      | professional athlete, labor job, 2-3 times per day |
# +-------------------+----------------------------------------------------+
# Your maintenance calories are  2548
# Please pick the appropriate activity level:
# +-------------------+----------------------------------------------------+
# | Activity Level    | Description                                        |
# +===================+====================================================+
# | Sedentary         | little to no activity                              |
# +-------------------+----------------------------------------------------+
# | Lightly Active    | 1-3 days per week of light activity                |
# +-------------------+----------------------------------------------------+
# | Moderately Active | moderate exercise 3-5 days per week                |
# +-------------------+----------------------------------------------------+
# | Very Active       | rigorous exercise, 6-7 days per week               |
# +-------------------+----------------------------------------------------+
# | Extra Active      | professional athlete, labor job, 2-3 times per day |
# +-------------------+----------------------------------------------------+
# Your maintenance calories are  1973
# Please pick the appropriate activity level:
# +-------------------+----------------------------------------------------+
# | Activity Level    | Description                                        |
# +===================+====================================================+
# | Sedentary         | little to no activity                              |
# +-------------------+----------------------------------------------------+
# | Lightly Active    | 1-3 days per week of light activity                |
# +-------------------+----------------------------------------------------+
# | Moderately Active | moderate exercise 3-5 days per week                |
# +-------------------+----------------------------------------------------+
# | Very Active       | rigorous exercise, 6-7 days per week               |
# +-------------------+----------------------------------------------------+
# | Extra Active      | professional athlete, labor job, 2-3 times per day |
# +-------------------+----------------------------------------------------+
# Your maintenance calories are  2836
# Tearing down the test class for EnergyRequirements.
# Setting up the test class for Goals.
# Your new daily caloric intake is  1514
# Tearing down the test class for Goals.
# Setting up the test class for WorkoutSchedule.
# Setting up before a test.
# Cleaning up after a test.
# Setting up before a test.
# +-------+----------------+------------+-----------+
# |  Day  |    Activity    |    Time    |  Period   |
# +=======+================+============+===========+
# | Day 1 |    Running     | 30 minutes |  Morning  |
# +-------+----------------+------------+-----------+
# | Day 2 |    Cycling     | 45 minutes |  Evening  |
# +-------+----------------+------------+-----------+
# | Day 3 |    Swimming    | 60 minutes | Afternoon |
# +-------+----------------+------------+-----------+
# | Day 4 |      Yoga      | 30 minutes |  Morning  |
# +-------+----------------+------------+-----------+
# | Day 5 | Weight Lifting | 45 minutes |  Evening  |
# +-------+----------------+------------+-----------+
# Cleaning up after a test.
# Setting up before a test.
#
# Updated Schedule:
# +-------+----------------+------------+-----------+
# |  Day  |    Activity    |    Time    |  Period   |
# +=======+================+============+===========+
# | Day 1 |     Tennis     | 60 minutes |  Morning  |
# +-------+----------------+------------+-----------+
# | Day 2 |    Cycling     | 45 minutes |  Evening  |
# +-------+----------------+------------+-----------+
# | Day 3 |    Swimming    | 60 minutes | Afternoon |
# +-------+----------------+------------+-----------+
# | Day 4 |      Yoga      | 30 minutes |  Morning  |
# +-------+----------------+------------+-----------+
# | Day 5 | Weight Lifting | 45 minutes |  Evening  |
# +-------+----------------+------------+-----------+
# Cleaning up after a test.
# Setting up before a test.
# No workout schedule found. Please generate one first.
# Cleaning up after a test.
# Tearing down the test class for WorkoutSchedule.
# Setting up the test class for Macros.
#
# Macronutrient Requirements:
# +---------------+-------------+------------+
# |   Protein (g) |   Carbs (g) |   Fats (g) |
# +===============+=============+============+
# |           150 |         200 |         67 |
# +---------------+-------------+------------+
#
# Generated Nutrition Plan:
# +-----------+--------------+-------------+-----------+----------+
# | Meal      | Calories     | Protein     | Carbs     | Fats     |
# +===========+==============+=============+===========+==========+
# | Breakfast | 600 calories | 45g protein | 60g carbs | 13g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Lunch     | 600 calories | 45g protein | 60g carbs | 13g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Dinner    | 600 calories | 45g protein | 15g carbs | 33g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Snacks    | 200 calories | 5g protein  | 5g carbs  | 2g fats  |
# +-----------+--------------+-------------+-----------+----------+
#
# Generated Nutrition Plan:
# +-----------+--------------+-------------+-----------+----------+
# | Meal      | Calories     | Protein     | Carbs     | Fats     |
# +===========+==============+=============+===========+==========+
# | Breakfast | 600 calories | 45g protein | 60g carbs | 13g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Lunch     | 600 calories | 45g protein | 60g carbs | 13g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Dinner    | 600 calories | 45g protein | 15g carbs | 33g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Snacks    | 200 calories | 5g protein  | 5g carbs  | 2g fats  |
# +-----------+--------------+-------------+-----------+----------+
#
# Generated Nutrition Plan:
#
# Generated Nutrition Plan:
# +-----------+--------------+-------------+-----------+----------+
# | Meal      | Calories     | Protein     | Carbs     | Fats     |
# +===========+==============+=============+===========+==========+
# | Breakfast | 600 calories | 45g protein | 60g carbs | 13g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Lunch     | 600 calories | 45g protein | 60g carbs | 13g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Dinner    | 600 calories | 45g protein | 15g carbs | 33g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Snacks    | 200 calories | 5g protein  | 5g carbs  | 2g fats  |
# +-----------+--------------+-------------+-----------+----------+
#
# Generated Nutrition Plan:
# +-----------+--------------+-------------+-----------+----------+
# | Meal      | Calories     | Protein     | Carbs     | Fats     |
# +===========+==============+=============+===========+==========+
# | Breakfast | 600 calories | 45g protein | 60g carbs | 13g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Lunch     | 600 calories | 45g protein | 60g carbs | 13g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Dinner    | 600 calories | 45g protein | 15g carbs | 33g fats |
# +-----------+--------------+-------------+-----------+----------+
# | Snacks    | 200 calories | 5g protein  | 5g carbs  | 2g fats  |
# +-----------+--------------+-------------+-----------+----------+
# Tearing down the test class for Macros.
